# %% [markdown]
# # Assignment 1 <br> Muhammad Bilal Naseer  <br>202046892

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn
import seaborn as sns
from sklearn.model_selection import StratifiedKFold
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import precision_recall_curve, average_precision_score, accuracy_score, f1_score, precision_score, recall_score


# Reading the data from the files and storing them in the following dataframes.
df1 = pd.read_csv('A1_dataA.tsv', sep='\t')
df2 = pd.read_csv('A1_dataB.tsv', sep='\t')
custom_palette = {0: 'green', 1: 'yellow'}

# %%
fig, axes = plt.subplots(1, 5, figsize=(20, 5))

sns.kdeplot(x='X1', hue='class', data=df2, fill=True, ax=axes[0], common_norm=False, palette=custom_palette)
axes[0].set_title('Dataset B - X1 vs class')

sns.kdeplot(x='X2', hue='class', data=df2, fill=True, ax=axes[1], common_norm=False, palette=custom_palette)
axes[1].set_title('Dataset B - X2 vs class')

sns.kdeplot(x='X3', hue='class', data=df2, fill=True, ax=axes[2], common_norm=False, palette=custom_palette)
axes[2].set_title('Dataset B - X3 vs class')

sns.kdeplot(x='X4', hue='class', data=df2, fill=True, ax=axes[3], common_norm=False, palette=custom_palette)
axes[3].set_title('Dataset B - X4 vs class')

sns.kdeplot(x='X5', hue='class', data=df2, fill=True, ax=axes[4], common_norm=False, palette=custom_palette)
axes[4].set_title('Dataset B - X5 vs class')

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 5, figsize=(20, 5))

sns.boxplot(x='class', y='X1', data=df2, ax=axes[0], palette=custom_palette)
axes[0].set_title('Dataset B - X1 vs class')

sns.boxplot(x='class', y='X2', data=df2, ax=axes[1], palette=custom_palette)
axes[1].set_title('Dataset B - X2 vs class')

sns.boxplot(x='class', y='X3', data=df2, ax=axes[2], palette=custom_palette)
axes[2].set_title('Dataset B - X3 vs class')

sns.boxplot(x='class', y='X4', data=df2, ax=axes[3], palette=custom_palette)
axes[3].set_title('Dataset B - X4 vs class')

sns.boxplot(x='class', y='X5', data=df2, ax=axes[4], palette=custom_palette)
axes[4].set_title('Dataset B - X5 vs class')

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 5, figsize=(20, 5))

sns.violinplot(x='class', y='X1', data=df2, ax=axes[0], inner='quartile', palette=custom_palette)
axes[0].set_title('Dataset B - X1 vs class')

sns.violinplot(x='class', y='X2', data=df2, ax=axes[1], inner='quartile', palette=custom_palette)
axes[1].set_title('Dataset B - X2 vs class')

sns.violinplot(x='class', y='X3', data=df2, ax=axes[2], inner='quartile', palette=custom_palette)
axes[2].set_title('Dataset B - X3 vs class')

sns.violinplot(x='class', y='X4', data=df2, ax=axes[3], inner='quartile', palette=custom_palette)
axes[3].set_title('Dataset B - X4 vs class')

sns.violinplot(x='class', y='X5', data=df2, ax=axes[4], inner='quartile', palette=custom_palette)
axes[4].set_title('Dataset B - X5 vs class')

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 5, figsize=(20, 5))

sns.histplot(x='X1', hue='class', data=df2, element='step', stat='density', common_norm=False, ax=axes[0], palette=custom_palette)
axes[0].set_title('Dataset B - X1 vs class')

sns.histplot(x='X2', hue='class', data=df2, element='step', stat='density', common_norm=False, ax=axes[1], palette=custom_palette)
axes[1].set_title('Dataset B - X2 vs class')

sns.histplot(x='X3', hue='class', data=df2, element='step', stat='density', common_norm=False, ax=axes[2], palette=custom_palette)
axes[2].set_title('Dataset B - X3 vs class')

sns.histplot(x='X4', hue='class', data=df2, element='step', stat='density', common_norm=False, ax=axes[3], palette=custom_palette)
axes[3].set_title('Dataset B - X4 vs class')

sns.histplot(x='X5', hue='class', data=df2, element='step', stat='density', common_norm=False, ax=axes[4], palette=custom_palette)
axes[4].set_title('Dataset B - X5 vs class')

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 5, figsize=(20, 5))

sns.kdeplot(x='X1', hue='class', data=df1, fill=True, ax=axes[0], common_norm=False, palette=custom_palette)
axes[0].set_title('Dataset A - X1 vs class')

sns.kdeplot(x='X2', hue='class', data=df1, fill=True, ax=axes[1], common_norm=False, palette=custom_palette)
axes[1].set_title('Dataset A - X2 vs class')

sns.kdeplot(x='X3', hue='class', data=df1, fill=True, ax=axes[2], common_norm=False, palette=custom_palette)
axes[2].set_title('Dataset A - X3 vs class')

sns.kdeplot(x='X4', hue='class', data=df1, fill=True, ax=axes[3], common_norm=False, palette=custom_palette)
axes[3].set_title('Dataset A - X4 vs class')

sns.kdeplot(x='X5', hue='class', data=df1, fill=True, ax=axes[4], common_norm=False, palette=custom_palette)
axes[4].set_title('Dataset A - X5 vs class')

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 5, figsize=(20, 5))

sns.boxplot(x='class', y='X1', data=df1, ax=axes[0], palette=custom_palette)
axes[0].set_title('Dataset A - X1 vs class')

sns.boxplot(x='class', y='X2', data=df1, ax=axes[1], palette=custom_palette)
axes[1].set_title('Dataset A - X2 vs class')

sns.boxplot(x='class', y='X3', data=df1, ax=axes[2], palette=custom_palette)
axes[2].set_title('Dataset A - X3 vs class')

sns.boxplot(x='class', y='X4', data=df1, ax=axes[3], palette=custom_palette)
axes[3].set_title('Dataset A - X4 vs class')

sns.boxplot(x='class', y='X5', data=df1, ax=axes[4], palette=custom_palette)
axes[4].set_title('Dataset A - X5 vs class')

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 5, figsize=(20, 5))

sns.violinplot(x='class', y='X1', data=df1, ax=axes[0], inner='quartile', palette=custom_palette)
axes[0].set_title('Dataset A - X1 vs class')

sns.violinplot(x='class', y='X2', data=df1, ax=axes[1], inner='quartile', palette=custom_palette)
axes[1].set_title('Dataset A - X2 vs class')

sns.violinplot(x='class', y='X3', data=df1, ax=axes[2], inner='quartile', palette=custom_palette)
axes[2].set_title('Dataset A - X3 vs class')

sns.violinplot(x='class', y='X4', data=df1, ax=axes[3], inner='quartile', palette=custom_palette)
axes[3].set_title('Dataset A - X4 vs class')

sns.violinplot(x='class', y='X5', data=df1, ax=axes[4], inner='quartile', palette=custom_palette)
axes[4].set_title('Dataset A - X5 vs class')

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 5, figsize=(20, 5))

sns.histplot(x='X1', hue='class', data=df1, element='step', stat='density', common_norm=False, ax=axes[0], palette=custom_palette)
axes[0].set_title('Dataset A - X1 vs class')

sns.histplot(x='X2', hue='class', data=df1, element='step', stat='density', common_norm=False, ax=axes[1], palette=custom_palette)
axes[1].set_title('Dataset A - X2 vs class')

sns.histplot(x='X3', hue='class', data=df1, element='step', stat='density', common_norm=False, ax=axes[2], palette=custom_palette)
axes[2].set_title('Dataset A - X3 vs class')

sns.histplot(x='X4', hue='class', data=df1, element='step', stat='density', common_norm=False, ax=axes[3], palette=custom_palette)
axes[3].set_title('Dataset A - X4 vs class')

sns.histplot(x='X5', hue='class', data=df1, element='step', stat='density', common_norm=False, ax=axes[4], palette=custom_palette)
axes[4].set_title('Dataset A - X5 vs class')

plt.tight_layout()
plt.show()

# %%
def knn_cross_validation(X, y, k, folds=10):
    skf = StratifiedKFold(n_splits=folds, shuffle=True, random_state=42)
    
    avg_precision_list = []
    accuracy_list = []
    f1_list = []
    precision_list = []
    recall_list = []

    for train_index, test_index in skf.split(X, y):
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]

        # Create and train KNN model
        knn = KNeighborsClassifier(n_neighbors=k)
        knn.fit(X_train, y_train)

        # Predictions
        y_pred = knn.predict(X_test)

        # Evaluate performance metrics
        precision, recall, _ = precision_recall_curve(y_test, knn.predict_proba(X_test)[:, 1])
        avg_precision = average_precision_score(y_test, knn.predict_proba(X_test)[:, 1])

        avg_precision_list.append(avg_precision)
        accuracy_list.append(accuracy_score(y_test, y_pred))
        f1_list.append(f1_score(y_test, y_pred))
        precision_list.append(precision_score(y_test, y_pred))
        recall_list.append(recall_score(y_test, y_pred))

        # Plot Precision-Recall curve for each fold
        plt.plot(recall, precision, lw=2)

    # Plot the average Precision-Recall curve
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.title('Precision-Recall Curve (KNN)')
    plt.show()

    # Return average performance metrics
    return {
        'avg_precision': np.mean(avg_precision_list),
        'accuracy': np.mean(accuracy_list),
        'f1': np.mean(f1_list),
        'precision': np.mean(precision_list),
        'recall': np.mean(recall_list),
    }


results_A = knn_cross_validation(df1.iloc[:, :-1], df1['class'],5)
print(results_A)

results_B = knn_cross_validation(df2.iloc[:, :-1], df2['class'],3)
print(results_B)
# Out:
# {'avg_precision': 0.5757420634920635, 'accuracy': 0.63, 'f1': 0.48492063492063486, 'precision': 0.6483333333333333, 'recall': 0.42000000000000004}
# {'avg_precision': 0.8749761904761904, 'accuracy': 0.8, 'f1': 0.7749494949494948, 'precision': 0.8633333333333333, 'recall': 0.72}
